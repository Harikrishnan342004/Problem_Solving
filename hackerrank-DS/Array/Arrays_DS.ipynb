# %%
#Arrays - DS..
def reverseArray(a):
    a.reverse()
    # x = reversed(a)
    return a
    # target = []
    # for i in a:
    #     target =  [i] +target
    # return target
A = [1 , 2 ,3, 4]
Input = reverseArray(A)
print(Input)
# Out:
# [4, 3, 2, 1]
