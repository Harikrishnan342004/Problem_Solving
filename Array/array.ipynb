# %%
#Array Num distance
def  Array_dis(Input , start , final):
    count = 0
    for element in Input:
        if(Input[])
    return

Input = [2,3,4,5,6,7,88,56,89]
start = 2
final = 6
Output = Array_dis(Input , start , final)
print(Output)   #Output is 4
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 8>()
#       6 start = 2
#       7 final = 6
# ----> 8 Output = Array_dis(Input , start , final)
#       9 print(Output)
#
# TypeError: Array_dis() takes 1 positional argument but 3 were given
